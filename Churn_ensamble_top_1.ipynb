# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool, cv, CatBoostRegressor
from sklearn.model_selection import train_test_split
import datetime
from scipy.stats import mode, poisson, binom
from scipy.stats import mode
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, RobustScaler, MinMaxScaler, OrdinalEncoder, MaxAbsScaler, Normalizer
from boruta import BorutaPy
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit, KFold
from tqdm.notebook import tqdm
import optuna
from optuna.samplers import TPESampler
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate
from sksurv.ensemble import GradientBoostingSurvivalAnalysis

# %%
import scipy
import implicit

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder, Normalizer, StandardScaler, MinMaxScaler
from sklearn.metrics import roc_curve, roc_auc_score

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from adabelief_pytorch import AdaBelief
import time

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from lifelines.utils import concordance_index

# %%
cat_col = ['most_season_of_year__agg_user', 'most_time_of_day__agg_user', 'employee_count_nm']

# %%
best_xgb_params_1 = {'n_estimators': 853,
             'learning_rate': 0.013661226489861992,
             'gamma': 0.11696969571136726,
             'subsample': 0.8049967773710163,
             'colsample_bytree': 0.3339055630223215,
             'max_depth': 7,
             'min_child_weight': 20,
             'reg_lambda': 3.889298224761356e-08,
             'reg_alpha': 3.2391819292617063e-06}

best_xgb_params_1['booster'] = 'gbtree'
best_xgb_params_1['grow_policy'] = 'depthwise'
best_xgb_params_1['objective'] = 'binary:logistic'  # Change to binary:logistic for binary classification
best_xgb_params_1["tree_method"] = "hist"
best_xgb_params_1["device"] = "cuda"
best_xgb_params_1["verbosity"] = 0

best_xgb_params_2 = {'n_estimators': 628,
 'learning_rate': 0.011748077668768182,
 'gamma': 0.31412508230969277,
 'subsample': 0.9558366431635512,
 'colsample_bytree': 0.11467178668260138,
 'max_depth': 12,
 'min_child_weight': 41,
 'reg_lambda': 0.07209060869092707,
 'reg_alpha': 0.00011424097075460839}

best_xgb_params_2['booster'] = 'gbtree'
best_xgb_params_2['grow_policy'] = 'depthwise'
best_xgb_params_2['objective'] = 'binary:logistic'  # Change to binary:logistic for binary classification
best_xgb_params_2["tree_method"] = "hist"
best_xgb_params_2["device"] = "cuda"
best_xgb_params_2["verbosity"] = 0


best_xgb_params_3 = {'n_estimators': 745, 
                     'learning_rate': 0.010107163356923585, 
                     'gamma': 0.1264925762995308, 
                     'subsample': 0.7739876750886237, 
                     'colsample_bytree': 0.5179473786776867, 
                     'max_depth': 8, 'min_child_weight': 26, 
                     'reg_lambda': 8.44621455470876e-08,
                     'reg_alpha': 0.2801246418297865}

best_xgb_params_3['booster'] = 'gbtree'
best_xgb_params_3['grow_policy'] = 'depthwise'
best_xgb_params_3['objective'] = 'binary:logistic'  # Change to binary:logistic for binary classification
best_xgb_params_3["tree_method"] = "hist"
best_xgb_params_3["device"] = "cuda"
best_xgb_params_3["verbosity"] = 0

best_xgb_params_4 = {'n_estimators': 922,
                     'learning_rate': 0.025507599212763642,
                     'gamma': 0.1865581414149164,
                     'subsample': 0.7854537340786112,
                     'colsample_bytree': 0.18369851525898526,
                     'max_depth': 3,
                     'min_child_weight': 47,
                     'reg_lambda': 1.1449260032403026e-08,
                     'reg_alpha': 8.40155861926593e-07}


best_xgb_params_4['booster'] = 'gbtree'
best_xgb_params_4['grow_policy'] = 'depthwise'
best_xgb_params_4['objective'] = 'binary:logistic'  # Change to binary:logistic for binary classification
best_xgb_params_4["tree_method"] = "hist"
best_xgb_params_4["device"] = "cuda"
best_xgb_params_4["verbosity"] = 0

best_xgb_params_5 = {'n_estimators': 955,
                     'learning_rate': 0.0102295236358994,
                     'gamma': 0.12023113482682993,
                     'subsample': 0.7648289898116127,
                     'colsample_bytree': 0.14129164111226958,
                     'max_depth': 19,
                     'min_child_weight': 63,
                     'reg_lambda': 3.9940671975904127e-07,
                     'reg_alpha': 8.480174695491063e-07}


best_xgb_params_5['booster'] = 'gbtree'
best_xgb_params_5['grow_policy'] = 'depthwise'
best_xgb_params_5['objective'] = 'binary:logistic'  # Change to binary:logistic for binary classification
best_xgb_params_5["tree_method"] = "hist"
best_xgb_params_5["device"] = "cuda"
best_xgb_params_5["verbosity"] = 0


cat_params_1 = {'iterations': 1184,
                'colsample_bylevel': 0.13040257880154318,
                'depth': 8, 'bootstrap_type': 'Bernoulli', 
                'l2_leaf_reg': 8.753773264677827, 
                'subsample': 0.5616578823756693,
                'scale_pos_weight': 1.1976750349743144,
                'random_strength': 0.47991140165950263, 
                'learning_rate': 0.019494278196021158, 
                'min_data_in_leaf': 7, 
                'cat_features': ['most_season_of_year__agg_user', 'most_time_of_day__agg_user', 'employee_count_nm'], 
                'boosting_type': 'Plain'}
cat_params_1['cat_features'] = cat_col 


cat_params_2 = {'iterations': 1311, 
                     'colsample_bylevel': 0.17551738677583945, 
                     'depth': 8, 
                     'bootstrap_type': 'MVS', 
                     'l2_leaf_reg': 4.67550056352784, 
                     'subsample': 0.9598936888218437, 
                     'scale_pos_weight': 1.8658056002484495,
                     'random_strength': 0.7825708527712321,
                     'learning_rate': 0.01799664439469639,
                     'min_data_in_leaf': 4,
                     'cat_features': ['most_season_of_year__agg_user', 'most_time_of_day__agg_user', 'employee_count_nm'],
                     'boosting_type': 'Plain'}

cat_params_2['cat_features'] = cat_col 


cat_params_3 = {'iterations': 1686, 
                'colsample_bylevel': 0.05121006576516264,
                'depth': 7, 
                'bootstrap_type': 'MVS', 
                'l2_leaf_reg': 9.493488381702742, 
                'subsample': 0.9193206638386658, 
                'scale_pos_weight': 2.88339175372185,
                'random_strength': 1.2280684827664923, 
                'learning_rate': 0.012156360604622102, 
                'min_data_in_leaf': 3, 
                'cat_features': ['most_season_of_year__agg_user', 'most_time_of_day__agg_user', 'employee_count_nm'], 
                'boosting_type': 'Plain'}
cat_params_3['cat_features'] = cat_col 

cat_params_4 = {'iterations': 1868,
                 'colsample_bylevel': 0.09129306235739947,
                 'depth': 8,
                 'bootstrap_type': 'Bernoulli',
                 'l2_leaf_reg': 4.824444180046867,
                 'subsample': 0.6830663196625929,
                 'scale_pos_weight': 0.6771106314182298,
                 'random_strength': 1.1902235753383072,
                 'learning_rate': 0.024939664452549727,
                 'min_data_in_leaf': 3}
cat_params_4['cat_features'] = cat_col 

params_xgb = [best_xgb_params_1, best_xgb_params_2, best_xgb_params_3,  best_xgb_params_4,  best_xgb_params_5]
params_cat = [cat_params_1, cat_params_2, cat_params_3, cat_params_4]

# %%
# class NET(nn.Module):
#     def __init__(self, input_size, hidden_size, output_size,num_layers=1, dropout=0.0):
#         super().__init__()

#         self.mlp = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.BatchNorm1d(hidden_size),
#             nn.ReLU(),                               #nn.Sigmoid nn.ReLU nn.LeakyReLU() nn.ELU() nn.Tanh()
#             nn.Linear(hidden_size, input_size),
#             nn.ReLU(),
#         )
        
#         self.encoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
#         self.decoder = nn.GRU(hidden_size, input_size, num_layers, batch_first=True)
        
#         self.fc = nn.Sequential(
            
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Dropout(dropout),
#             nn.Linear(256, 128),
#             nn.BatchNorm1d(128),
#             nn.ReLU(),
#             nn.Dropout(dropout),
#             nn.Linear(128, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(dropout),
#             nn.Linear(64, output_size),
#             nn.Sigmoid())
        
#     def forward(self, x):
#         x = x.float()
#         x = self.mlp(x)
        
#         # Передайте x в LSTM как последовательность данных
#         output, _ = self.encoder(x)
#         # Передайте выход из первого LSTM во второй LSTM
#         output, _ = self.decoder(output)
#         probabilities = self.fc(output) 
#         return probabilities

# %%
df_client = pd.read_csv('clients.csv')
df_currency = pd.read_csv('currency_rk.csv')
df_mcc_codes = pd.read_csv('mcc_codes.csv')
df_report_dates = pd.read_csv('report_dates.csv')
df_transactions = pd.read_csv('transactions.csv')
df_train = pd.read_csv('train.csv')
fun_agg = ['count',  'sum','median','std','nunique']
fun_agg_min = ['sum','median','count']
df_transactions['sign'] = df_transactions['transaction_amt'].apply(lambda x: 'positive' if x >= 0 else 'negative')
df_client = df_client.merge(df_report_dates, on='report')
df_transactions = df_transactions.merge(df_client, on='user_id')
df_transactions[['currency_rk']] = df_transactions[['currency_rk']].map(lambda x: 0 if x != 1 else 1)
df_transactions['transaction_dttm'] = pd.to_datetime(df_transactions['transaction_dttm'])
df_transactions['day'] = df_transactions['transaction_dttm'].dt.day_of_year.astype(int)
df_transactions['transaction_dttm'] = pd.to_datetime(df_transactions['transaction_dttm'])
df_transactions['date'] = df_transactions['transaction_dttm'].dt.date
df_transactions['report_dt'] = pd.to_datetime(df_transactions['report_dt']).dt.date
df_transactions['delta_date'] = df_transactions['report_dt'] - df_transactions['date']
df_transactions.delta_date= df_transactions.delta_date.map(lambda x: x.days)
df_transactions['employee_count_nm'] = df_transactions['employee_count_nm'].fillna('НЕИЗВЕСТНО')
df_transactions
# Out:
#           user_id  mcc_code  currency_rk  transaction_amt    transaction_dttm  \
# 0               3         3            1          -183.88 2022-01-28 12:05:33
# 1               3         3            1         -3206.44 2022-01-28 12:52:30
# 2               3        16            1       -153866.89 2022-02-16 14:45:56
# 3               3        56            1        -15144.60 2022-03-09 19:58:29
# 4               3         0            1          5297.91 2022-03-12 18:11:31
# ...           ...       ...          ...              ...                 ...
# 13075018   562740       155            1         -2484.37 2023-03-20 11:52:09
# 13075019   562740         9            1          -187.66 2023-03-20 12:10:22
# 13075020   562740         1            1          -891.93 2023-03-20 15:53:37
# 13075021   562740        13            1          -464.47 2023-03-20 15:54:49
# 13075022   562740         9            1          -188.75 2023-03-20 16:06:45
#
#               sign  report employee_count_nm  bankemplstatus  customer_age  \
# 0         negative       2     ОТ 101 ДО 500               0             3
# 1         negative       2     ОТ 101 ДО 500               0             3
# 2         negative       2     ОТ 101 ДО 500               0             3
# 3         negative       2     ОТ 101 ДО 500               0             3
# 4         positive       2     ОТ 101 ДО 500               0             3
# ...            ...     ...               ...             ...           ...
# 13075018  negative      12        НЕИЗВЕСТНО               0             0
# 13075019  negative      12        НЕИЗВЕСТНО               0             0
# 13075020  negative      12        НЕИЗВЕСТНО               0             0
# 13075021  negative      12        НЕИЗВЕСТНО               0             0
# 13075022  negative      12        НЕИЗВЕСТНО               0             0
#
#            report_dt  day        date  delta_date
# 0         2022-08-31   28  2022-01-28         215
# 1         2022-08-31   28  2022-01-28         215
# 2         2022-08-31   47  2022-02-16         196
# 3         2022-08-31   68  2022-03-09         175
# 4         2022-08-31   71  2022-03-12         172
# ...              ...  ...         ...         ...
# 13075018  2023-06-30   79  2023-03-20         102
# 13075019  2023-06-30   79  2023-03-20         102
# 13075020  2023-06-30   79  2023-03-20         102
# 13075021  2023-06-30   79  2023-03-20         102
# 13075022  2023-06-30   79  2023-03-20         102
#
# [13075023 rows x 14 columns]

# %%
t_d = df_transactions.groupby(['user_id','day'])['day'].count() 
t1 = t_d[t_d>20].unstack()
t2 = df_train[['user_id']].merge(t1, on='user_id')

#Объедененные фичи
t = pd.read_csv('features_X_train__v3.csv')
t = t[~t['user_id'].isin(t2['user_id'])]
X = t.drop('target', axis=1)
y = t['target']


#Определение категориальных
cat_col = X.select_dtypes(include=['object']).columns.tolist()
y.shape, X.shape
# Out:
# ((63704,), (63704, 1154))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,\
                        test_size = 0.20, random_state = 142, stratify=y)
# print(x_train.shape)
# x_concat = []
# y_concat = []
# for i in tqdm(range(35)):
#     x_x = x_train.loc[y_train[y_train == 1]]
#     y_x = y_train[y_train == 1]
#     x_concat.append(x_x)
#     y_concat.append(y_x)


# x_train = pd.concat([x_train] + x_concat)
# y_train = pd.concat([y_train] + y_concat)
# x_train.index = range(x_train.shape[0])
# y_train.index = range(x_train.shape[0])
# x_train = x_train.sample(frac=1)
# y_train = y_train.loc[x_train.index]
# x_train.index = range(x_train.shape[0])
# y_train.index = range(x_train.shape[0])
                    


# print(x_train.shape[0], y_train.shape[0])

# %%
predictions = []
score = []

# %%
for i in tqdm(params_cat):
    catboost_model = CatBoostClassifier(verbose=False, **i)
    catboost_model.fit(x_train, y_train)
    predictions.append(catboost_model.predict_proba(x_test)[:,1])
    scors = concordance_index(y_test, catboost_model.predict_proba(x_test)[:,1])
    score.append(scors)
    print(scors)
    print('----------------------------------------------')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 0.7876789422139867
# ----------------------------------------------
# 0.7855657084378005
# ----------------------------------------------
# 0.7879792312121185
# ----------------------------------------------
# 0.7882697508081777
# ----------------------------------------------

# %%
for i in tqdm(params_xgb):
    model_xgb = XGBClassifier(**i)
    model_xgb.fit(x_train.drop(cat_col, axis=1),y_train)
    predictions.append(model_xgb.predict_proba(x_test.drop(cat_col, axis=1))[:,1])
    scors = concordance_index(y_test, model_xgb.predict_proba(x_test.drop(cat_col, axis=1))[:,1])
    score.append(scors)
    print(scors)
    print('----------------------------------------------')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0.7872767551491555
# ----------------------------------------------
# 0.7895586312266926
# ----------------------------------------------
# 0.7871396632118751
# ----------------------------------------------
# 0.7911592116252681
# ----------------------------------------------
# 0.7899458438801502
# ----------------------------------------------

# %%
# # Случайное масштабирование и смещение
# def scale_and_shift(dataframe):
#     scaled_shifted_df = dataframe.copy()
#     for col in scaled_shifted_df.columns:
#             scaler = MinMaxScaler(feature_range=(0, 20))
#             scaled_shifted_df[col] = scaler.fit_transform(scaled_shifted_df[[col]])
#     return scaled_shifted_df

# %%
# x_train, x_test, y_train, y_test = train_test_split(X.drop(cat_col,axis=1), y,\
#                         test_size = 0.20, random_state = 142, stratify=y)
# # print(x_train.shape)
# # x_concat = []
# # y_concat = []
# # for i in tqdm(range(35)):
# #     x_x = scale_and_shift(x_train.loc[y_train[y_train == 1]])
# #     y_x = y_train[y_train == 1]
# #     x_concat.append(x_x)
# #     y_concat.append(y_x)


# # x_train = pd.concat([x_train] + x_concat)
# # y_train = pd.concat([y_train] + y_concat)
# # x_train.index = range(x_train.shape[0])
# # y_train.index = range(x_train.shape[0])
# # x_train = x_train.sample(frac=1)
# # y_train = y_train.loc[x_train.index]
# # x_train.index = range(x_train.shape[0])
# # y_train.index = range(x_train.shape[0])

# # print(x_train.shape[0], y_train.shape[0])

# %%
# X_tr = torch.tensor(MinMaxScaler(feature_range=(0, 15)).fit_transform(x_train)) #MinMaxScaler  StandardScaler  MaxAbsScaler Normalizer

# X_te = torch.tensor(MinMaxScaler(feature_range=(0, 15)).fit_transform(x_test))

# X_padded = X_tr.long()
# y_tensor = torch.tensor(y_train.values)


# X_padded_test = X_te
# y_tensor_test = torch.tensor(y_test.values)

# # Создание набора данных и загузчика данных
# dataset = TensorDataset(X_padded, y_tensor)
# dataset_test = TensorDataset(X_padded_test, y_tensor_test)

# dataloader = DataLoader(dataset, batch_size=2512, shuffle=True)
# test_dataloader = DataLoader(dataset_test, batch_size=512, shuffle=False)

# input_size = X_te.shape[-1]
# hidden_size = 128
# output_size = 1

# model = NET(input_size, hidden_size, output_size,num_layers=2, dropout=0.)
# # Сохранение и загрузка весов модели
# MODEL_PATH = 'model_weight_NET_.pth'


# model.load_state_dict(torch.load(MODEL_PATH))
# print("Загружены предыдущие веса модели.")

# X_padded_test = torch.tensor(MinMaxScaler(feature_range=(0, 15)).fit_transform(x_test))
# # тестирование модели после каждой эпохи
# model.eval().to('cpu')  # переводим модель в режим оценки
# with torch.no_grad():  # отключаем вычисление градиентов
#             outputs = model(X_padded_test)
#             predictions.append(outputs.view(-1).to('cpu').numpy())
#             score.append(concordance_index(y_test,outputs.view(-1).to('cpu').numpy()))

# %%
score
# Out:
# [0.7876789422139867,
#  0.7855657084378005,
#  0.7879792312121185,
#  0.7882697508081777,
#  0.7872767551491555,
#  0.7895586312266926,
#  0.7871396632118751,
#  0.7911592116252681,
#  0.7899458438801502]

# %%
# Подбор весов для объеденения моделей
def objective(trial):
    weights = []
    for i in range(len(predictions)):
        weights.append(trial.suggest_float(f'weight_model{i}', 0.0, 1.0))
    # Используйте ваши модели и данные для расчета предсказаний ансамбля
    ensemble_predictions = np.average(predictions, axis=0, weights=weights)
    # Оцените производительность ансамбля
    score = concordance_index(y_test,  ensemble_predictions)
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=3000)

best_weights = study.best_params
# Out:
# [I 2024-04-09 00:22:19,134] A new study created in memory with name: no-name-b80d985b-7877-4b27-9b80-49d16e944d0e
# [I 2024-04-09 00:22:19,270] Trial 0 finished with value: 0.7904266265854258 and parameters: {'weight_model0': 0.9828091576626773, 'weight_model1': 0.29336758386166073, 'weight_model2': 0.9920690075030836, 'weight_model3': 0.7475525110681411, 'weight_model4': 0.462560641621942, 'weight_model5': 0.4782472635116075, 'weight_model6': 0.8908964418750702, 'weight_model7': 0.7900315935834392, 'weight_model8': 0.018288032110109764}. Best is trial 0 with value: 0.7904266265854258.
# [I 2024-04-09 00:22:19,404] Trial 1 finished with value: 0.790327411100443 and parameters: {'weight_model0': 0.45060502073067243, 'weight_model1': 0.5611691405518296, 'weight_model2': 0.196096882329159, 'weight_model3': 0.2979119459614097, 'weight_model4': 0.9321131222615047, 'weight_model5': 0.663982578290478, 'weight_model6': 0.6208167135678271, 'weight_model7': 0.39704798515000794, 'weight_model8': 0.24849092701048103}. Best is trial 0 with value: 0.7904266265854258.
# [I 2024-04-09 00:22:19,530] Trial 2 finished with value: 0.7902458926470836 and parameters: {'weight_model0': 0.7225735183495846, 'weight_model1': 0.3892908286742175, 'weight_model2': 0.8080291909339982, 'weight_model3': 0.4975716968950148, 'weight_model4': 0.06873071198182612, 'weight_model5': 0.6588083148254135, 'weight_model6': 0.9076839755992699, 'weight_model7': 0.06726921792457718, 'weight_model8': 0.5091315910366548}. Best is trial 0 with value: 0.7904266265854258.
# [I 2024-04-09 00:22:19,657] Trial 3 finished with value: 0.7902528593518402 and parameters: {'weight_model0': 0.881734094485469, 'weight_model1': 0.8833012258888879, 'weight_model2': 0.9920200093666114, 'weight_model3': 0.418221211064266, 'weight_model4': 0.5954326015322655, 'weight_model5': 0.5291803682504154, 'weight_model6': 0.6737868406784253, 'weight_model7': 0.9803970004488113, 'weight_model8': 0.06319519105159421}. Best is trial 0 with value: 0.7904266265854258.
# [I 2024-04-09 00:22:19,785] Trial 4 finished with value: 0.790576931238624 and parameters: {'weight_model0': 0.8307179109008419, 'weight_model1': 0.681419291773352, 'weight_model2': 0.8026686297638842, 'weight_model3': 0.874296058185058, 'weight_model4': 0.5241162141032703, 'weight_model5': 0.863833301018746, 'weight_model6': 0.428356812721122, 'weight_model7': 0.7019525282613202, 'weight_model8': 0.4426656764022143}. Best is trial 4 with value: 0.790576931238624.
# [I 2024-04-09 00:22:19,925] Trial 5 finished with value: 0.7906874375899365 and parameters: {'weight_model0': 0.6047983605648938, 'weight_model1': 0.20549434817601298, 'weight_model2': 0.7420352728715438, 'weight_model3': 0.12828980143220559, 'weight_model4': 0.4842247032137912, 'weight_model5': 0.6668724615434952, 'weight_model6': 0.6107144167171216, 'weight_model7': 0.6380367331284754, 'weight_model8': 0.3983595342842443}. Best is trial 5 with value: 0.7906874375899365.
# [I 2024-04-09 00:22:20,053] Trial 6 finished with value: 0.7907187477228085 and parameters: {'weight_model0': 0.7231582976731185, 'weight_model1': 0.39807196489744445, 'weight_model2': 0.9109637034450908, 'weight_model3': 0.012313941053814337, 'weight_model4': 0.7189990913177603, 'weight_model5': 0.8545203892961283, 'weight_model6': 0.4034055039986906, 'weight_model7': 0.7235969954723184, 'weight_model8': 0.9590140449108527}. Best is trial 6 with value: 0.7907187477228085.
# [I 2024-04-09 00:22:20,195] Trial 7 finished with value: 0.7903798615787834 and parameters: {'weight_model0': 0.2143739771084604, 'weight_model1': 0.4118113086582511, 'weight_model2': 0.6133838075409593, 'weight_model3': 0.9981654280675105, 'weight_model4': 0.24368189537145557, 'weight_model5': 0.20709801399638783, 'weight_model6': 0.7046055765863269, 'weight_model7': 0.26583682994304736, 'weight_model8': 0.4577657900516575}. Best is trial 6 with value: 0.7907187477228085.
# [I 2024-04-09 00:22:20,326] Trial 8 finished with value: 0.7907265151982268 and parameters: {'weight_model0': 0.310420464831373, 'weight_model1': 0.17229961867970922, 'weight_model2': 0.9246712757453791, 'weight_model3': 0.3845943824885476, 'weight_model4': 0.9231008944587786, 'weight_model5': 0.6396393406802329, 'weight_model6': 0.2289555374035448, 'weight_model7': 0.9306987259403282, 'weight_model8': 0.14466182725182453}. Best is trial 8 with value: 0.7907265151982268.
# [I 2024-04-09 00:22:20,454] Trial 9 finished with value: 0.7904359155251014 and parameters: {'weight_model0': 0.8377985539710447, 'weight_model1': 0.35900763958789894, 'weight_model2': 0.4477035412379997, 'weight_model3': 0.9236352702576001, 'weight_model4': 0.2578269684425861, 'weight_model5': 0.042459842471317066, 'weight_model6': 0.5043538536333538, 'weight_model7': 0.3267085150333153, 'weight_model8': 0.5195252343857748}. Best is trial 8 with value: 0.7907265151982268.
# [I 2024-04-09 00:22:20,617] Trial 10 finished with value: 0.7911060804918654 and parameters: {'weight_model0': 0.02369475053601533, 'weight_model1': 0.11321777020149965, 'weight_model2': 0.4767245362432768, 'weight_model3': 0.6690449491822363, 'weight_model4': 0.9599238986412664, 'weight_model5': 0.9982021591889453, 'weight_model6': 0.055430238520547265, 'weight_model7': 0.9184664201821453, 'weight_model8': 0.19998697642656643}. Best is trial 10 with value: 0.7911060804918654.
# [I 2024-04-09 00:22:20,792] Trial 11 finished with value: 0.79109783255405 and parameters: {'weight_model0': 0.02822466165485904, 'weight_model1': 0.046387665795218, 'weight_model2': 0.4814569151537813, 'weight_model3': 0.6566430473326224, 'weight_model4': 0.9723993875832184, 'weight_model5': 0.9981942285422248, 'weight_model6': 0.08976630879727816, 'weight_model7': 0.8768241208186184, 'weight_model8': 0.20154005900851832}. Best is trial 10 with value: 0.7911060804918654.
# [I 2024-04-09 00:22:20,968] Trial 12 finished with value: 0.7912185887698321 and parameters: {'weight_model0': 0.033859789936037304, 'weight_model1': 0.043503794031849785, 'weight_model2': 0.4586979206224362, 'weight_model3': 0.6740545153516131, 'weight_model4': 0.9991425088571545, 'weight_model5': 0.9804420069374334, 'weight_model6': 0.002878602132976041, 'weight_model7': 0.9988594772226533, 'weight_model8': 0.2346891965624854}. Best is trial 12 with value: 0.7912185887698321.
# [I 2024-04-09 00:22:21,129] Trial 13 finished with value: 0.7912971443717434 and parameters: {'weight_model0': 0.026910503200999806, 'weight_model1': 0.04049185537635233, 'weight_model2': 0.34156110391196276, 'weight_model3': 0.6292065419661204, 'weight_model4': 0.8084202099063329, 'weight_model5': 0.9854749471219642, 'weight_model6': 0.004578588918052113, 'weight_model7': 0.9577660997844879, 'weight_model8': 0.29140421071357103}. Best is trial 13 with value: 0.7912971443717434.
# [I 2024-04-09 00:22:21,283] Trial 14 finished with value: 0.7913280541192844 and parameters: {'weight_model0': 0.18278056856699734, 'weight_model1': 0.062110345306430455, 'weight_model2': 0.2815908516269313, 'weight_model3': 0.5635531819513161, 'weight_model4': 0.7779250669103895, 'weight_model5': 0.8501847334392794, 'weight_model6': 0.018844055473291522, 'weight_model7': 0.9832806442105353, 'weight_model8': 0.30861317256275267}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:21,436] Trial 15 finished with value: 0.7910931880842123 and parameters: {'weight_model0': 0.22116530609576188, 'weight_model1': 0.006490418896704028, 'weight_model2': 0.22946744763677243, 'weight_model3': 0.5603320076313516, 'weight_model4': 0.7788422716199106, 'weight_model5': 0.8491272338875421, 'weight_model6': 0.19632560894038498, 'weight_model7': 0.6108805275003, 'weight_model8': 0.33478144616477723}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:21,588] Trial 16 finished with value: 0.7911068011854608 and parameters: {'weight_model0': 0.15174570886593092, 'weight_model1': 0.25500698505972635, 'weight_model2': 0.09238710232459835, 'weight_model3': 0.7856569795386033, 'weight_model4': 0.7880324461073018, 'weight_model5': 0.8479709189417729, 'weight_model6': 0.19776726112864937, 'weight_model7': 0.8222806721444145, 'weight_model8': 0.32840826777043375}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:21,745] Trial 17 finished with value: 0.7912342838748011 and parameters: {'weight_model0': 0.3542195031221846, 'weight_model1': 0.15275231523207547, 'weight_model2': 0.3304512151147708, 'weight_model3': 0.5486906828968467, 'weight_model4': 0.68625840305398, 'weight_model5': 0.7588982715943822, 'weight_model6': 0.11588410604072842, 'weight_model7': 0.8475661293070205, 'weight_model8': 0.5884493713068784}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:21,896] Trial 18 finished with value: 0.7911045590276081 and parameters: {'weight_model0': 0.12929201242250973, 'weight_model1': 0.12065142790551169, 'weight_model2': 0.04997284911930744, 'weight_model3': 0.5954248917647524, 'weight_model4': 0.8134504115429673, 'weight_model5': 0.92400948374813, 'weight_model6': 0.015315766692981668, 'weight_model7': 0.5825313929877676, 'weight_model8': 0.6172543884949183}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,059] Trial 19 finished with value: 0.7909623421580929 and parameters: {'weight_model0': 0.3576635073074403, 'weight_model1': 0.27793661598900904, 'weight_model2': 0.3431736375565613, 'weight_model3': 0.7953619650363534, 'weight_model4': 0.8433133728749347, 'weight_model5': 0.7524819346788383, 'weight_model6': 0.2761604324783607, 'weight_model7': 0.7659093343714977, 'weight_model8': 0.3238124016639242}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,214] Trial 20 finished with value: 0.7911981691179591 and parameters: {'weight_model0': 0.11591597174908666, 'weight_model1': 0.039091582131551846, 'weight_model2': 0.003353338430249264, 'weight_model3': 0.4686177132519258, 'weight_model4': 0.6582060610997267, 'weight_model5': 0.9363027770223465, 'weight_model6': 0.2838110009189033, 'weight_model7': 0.9782283065726319, 'weight_model8': 0.09381756805892277}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,366] Trial 21 finished with value: 0.7912464555888588 and parameters: {'weight_model0': 0.3059720899177718, 'weight_model1': 0.15285006641033305, 'weight_model2': 0.33604698896091534, 'weight_model3': 0.5582018838239354, 'weight_model4': 0.6567218639590161, 'weight_model5': 0.7682689627381405, 'weight_model6': 0.11776167094629995, 'weight_model7': 0.8573671470622622, 'weight_model8': 0.6033367742268974}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,521] Trial 22 finished with value: 0.7912055362080467 and parameters: {'weight_model0': 0.24805592391397527, 'weight_model1': 0.12042125971876665, 'weight_model2': 0.33838205967978013, 'weight_model3': 0.6121735450122663, 'weight_model4': 0.8551245054848776, 'weight_model5': 0.7741391542012241, 'weight_model6': 0.12485273401509722, 'weight_model7': 0.8934515545789662, 'weight_model8': 0.6669488014672686}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,675] Trial 23 finished with value: 0.7912937010578981 and parameters: {'weight_model0': 0.12199972447119642, 'weight_model1': 0.011371966271582615, 'weight_model2': 0.2333700442848543, 'weight_model3': 0.5314284770075988, 'weight_model4': 0.7295518519436716, 'weight_model5': 0.9082545104469899, 'weight_model6': 0.12192010750107071, 'weight_model7': 0.8582799554939873, 'weight_model8': 0.694916787186468}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,828] Trial 24 finished with value: 0.7912561449138651 and parameters: {'weight_model0': 0.10262556447805143, 'weight_model1': 0.0003134840862159538, 'weight_model2': 0.1856600902766199, 'weight_model3': 0.3743239108180053, 'weight_model4': 0.7599731428098058, 'weight_model5': 0.9169805589031756, 'weight_model6': 0.01663837274183248, 'weight_model7': 0.7950564288445834, 'weight_model8': 0.740706027202812}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:22,981] Trial 25 finished with value: 0.7910857409170585 and parameters: {'weight_model0': 0.17816406600425494, 'weight_model1': 0.2424860536233631, 'weight_model2': 0.26611848440202573, 'weight_model3': 0.4835063361780697, 'weight_model4': 0.8802974711671407, 'weight_model5': 0.9115187013051773, 'weight_model6': 0.15585171432583952, 'weight_model7': 0.9375208559699819, 'weight_model8': 0.38560949777743403}. Best is trial 14 with value: 0.7913280541192844.
# [I 2024-04-09 00:22:23,141] Trial 26 finished with value: 0.791364969646788 and parameters: {'weight_model0': 0.06726571949980185, 'weight_model1': 0.07692636443007021, 'weight_model2': 0.15577251824107752, 'weight_model3': 0.7283003056188667, 'weight_model4': 0.7432902906551341, 'weight_model5': 0.9826021440758913, 'weight_model6': 0.07401664910346623, 'weight_model7': 0.9984443025741863, 'weight_model8': 0.76566489189652}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:23,296] Trial 27 finished with value: 0.7912631916956879 and parameters: {'weight_model0': 0.04350236830208673, 'weight_model1': 0.10411811080006583, 'weight_model2': 0.08782716552844061, 'weight_model3': 0.7159105382193807, 'weight_model4': 0.8715420083392794, 'weight_model5': 0.9830876678089705, 'weight_model6': 0.04876586104861631, 'weight_model7': 0.9675443244140374, 'weight_model8': 0.8343148475991243}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:23,449] Trial 28 finished with value: 0.791073569203001 and parameters: {'weight_model0': 0.08191361545756634, 'weight_model1': 0.20866641038815073, 'weight_model2': 0.1312447326690016, 'weight_model3': 0.8142450264928492, 'weight_model4': 0.7915474771975112, 'weight_model5': 0.8204564533918147, 'weight_model6': 0.2922997978658663, 'weight_model7': 0.7358778704696907, 'weight_model8': 0.5344829546013289}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:23,601] Trial 29 finished with value: 0.7912848925806196 and parameters: {'weight_model0': 0.0005656703202631674, 'weight_model1': 0.3362467700537483, 'weight_model2': 0.1493531038969086, 'weight_model3': 0.7278345822697616, 'weight_model4': 0.6174296436747317, 'weight_model5': 0.9208624164823075, 'weight_model6': 0.0008619220262315042, 'weight_model7': 0.9947401483402206, 'weight_model8': 0.281421100405513}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:23,754] Trial 30 finished with value: 0.7910077458546104 and parameters: {'weight_model0': 0.1757945103523569, 'weight_model1': 0.28262234147301185, 'weight_model2': 0.2714270476581194, 'weight_model3': 0.6391593958876943, 'weight_model4': 0.5648945393182001, 'weight_model5': 0.38370838025672943, 'weight_model6': 0.07480858587806491, 'weight_model7': 0.8053409269371228, 'weight_model8': 0.020567381217265757}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:23,909] Trial 31 finished with value: 0.7912928202101702 and parameters: {'weight_model0': 0.10319592660277935, 'weight_model1': 0.08376135862603572, 'weight_model2': 0.2385688289931026, 'weight_model3': 0.7372188328514588, 'weight_model4': 0.7321541528535314, 'weight_model5': 0.8940024557105525, 'weight_model6': 0.16038732948549306, 'weight_model7': 0.8897761871697363, 'weight_model8': 0.7146373702009315}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,063] Trial 32 finished with value: 0.7913134000161756 and parameters: {'weight_model0': 0.09826013841323433, 'weight_model1': 0.06698695051757796, 'weight_model2': 0.188014312914762, 'weight_model3': 0.59050596426505, 'weight_model4': 0.7318456510651015, 'weight_model5': 0.9566425742854996, 'weight_model6': 0.07892918356869368, 'weight_model7': 0.9026802660128558, 'weight_model8': 0.7993472605915037}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,224] Trial 33 finished with value: 0.7912190692322291 and parameters: {'weight_model0': 0.0725252787888447, 'weight_model1': 0.0815278584210238, 'weight_model2': 0.14019710071850075, 'weight_model3': 0.6410675670563423, 'weight_model4': 0.9149109803432428, 'weight_model5': 0.9999078364150585, 'weight_model6': 0.07242340795486511, 'weight_model7': 0.92065213981004, 'weight_model8': 0.7951565002124862}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,385] Trial 34 finished with value: 0.7912848125035534 and parameters: {'weight_model0': 0.007225549490943006, 'weight_model1': 0.17642623246797676, 'weight_model2': 0.1765467739044673, 'weight_model3': 0.5895467190687165, 'weight_model4': 0.6856345190420673, 'weight_model5': 0.8212165828113315, 'weight_model6': 0.06905133315044548, 'weight_model7': 0.9297647234202764, 'weight_model8': 0.8738278821922266}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,544] Trial 35 finished with value: 0.7911944054958492 and parameters: {'weight_model0': 0.17618352612910532, 'weight_model1': 0.0800296044757374, 'weight_model2': 0.2878577629111735, 'weight_model3': 0.7012303951146244, 'weight_model4': 0.8432230649445204, 'weight_model5': 0.9484471857114696, 'weight_model6': 0.16477425959572017, 'weight_model7': 0.7867432432518918, 'weight_model8': 0.9146130037790389}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,702] Trial 36 finished with value: 0.7912413306566239 and parameters: {'weight_model0': 0.25518214524654886, 'weight_model1': 0.2137275581063388, 'weight_model2': 0.4077658817224506, 'weight_model3': 0.5126334579969548, 'weight_model4': 0.6120577089119168, 'weight_model5': 0.9522220399990338, 'weight_model6': 0.226761968564602, 'weight_model7': 0.9925099506357081, 'weight_model8': 0.9939127232766981}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:24,861] Trial 37 finished with value: 0.7910645204945239 and parameters: {'weight_model0': 0.07106865392517903, 'weight_model1': 0.4809182505549936, 'weight_model2': 0.20528906636990285, 'weight_model3': 0.6268849746084002, 'weight_model4': 0.7443091455349106, 'weight_model5': 0.8761505297504382, 'weight_model6': 0.05503048074506242, 'weight_model7': 0.8526045717091, 'weight_model8': 0.7714924886152085}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,016] Trial 38 finished with value: 0.7913147613263004 and parameters: {'weight_model0': 0.43658991466806085, 'weight_model1': 0.17037246418251006, 'weight_model2': 0.18579208998451038, 'weight_model3': 0.4259294446981089, 'weight_model4': 0.5420622674566302, 'weight_model5': 0.8024139254692477, 'weight_model6': 0.005242963496440975, 'weight_model7': 0.6922684004247929, 'weight_model8': 0.8204483819252755}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,173] Trial 39 finished with value: 0.7911341875420905 and parameters: {'weight_model0': 0.4508729806755134, 'weight_model1': 0.3129101439116556, 'weight_model2': 0.10445015222510015, 'weight_model3': 0.4436773939261065, 'weight_model4': 0.5599077702412146, 'weight_model5': 0.7040134108242186, 'weight_model6': 0.1210008993972967, 'weight_model7': 0.6457302387670645, 'weight_model8': 0.8297029720696035}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,330] Trial 40 finished with value: 0.7911761479247628 and parameters: {'weight_model0': 0.5577489229982545, 'weight_model1': 0.15434036890141478, 'weight_model2': 0.1627893823324163, 'weight_model3': 0.4134251237587841, 'weight_model4': 0.5175426662437872, 'weight_model5': 0.8014110438137863, 'weight_model6': 0.3610653448512548, 'weight_model7': 0.7258680145964596, 'weight_model8': 0.9082066468692443}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,492] Trial 41 finished with value: 0.7913620868724061 and parameters: {'weight_model0': 0.1425608270509518, 'weight_model1': 0.06387170807220278, 'weight_model2': 0.18462961317314092, 'weight_model3': 0.4660218859883452, 'weight_model4': 0.6977464000614559, 'weight_model5': 0.8599747161937837, 'weight_model6': 0.01739594238881499, 'weight_model7': 0.9356736836323432, 'weight_model8': 0.7545909210430348}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,651] Trial 42 finished with value: 0.7912360455702568 and parameters: {'weight_model0': 0.20529183626950642, 'weight_model1': 0.2084934508401195, 'weight_model2': 0.1874348682168846, 'weight_model3': 0.3364487665128063, 'weight_model4': 0.6959682681380263, 'weight_model5': 0.8789127953513691, 'weight_model6': 0.04934363913566141, 'weight_model7': 0.9106410921969776, 'weight_model8': 0.7513741363855441}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,818] Trial 43 finished with value: 0.7912780059529291 and parameters: {'weight_model0': 0.164347875131646, 'weight_model1': 0.07102970647880301, 'weight_model2': 0.20959830115921488, 'weight_model3': 0.2817083372962268, 'weight_model4': 0.6318717170667387, 'weight_model5': 0.7019421171318386, 'weight_model6': 0.09130752762570327, 'weight_model7': 0.8247813499480622, 'weight_model8': 0.7965692512671299}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:25,985] Trial 44 finished with value: 0.7912924198248394 and parameters: {'weight_model0': 0.2686360731337512, 'weight_model1': 0.1257206334801698, 'weight_model2': 0.06601203639386843, 'weight_model3': 0.5072960626076004, 'weight_model4': 0.4654799908413246, 'weight_model5': 0.8466350661689387, 'weight_model6': 0.16204417134666282, 'weight_model7': 0.6786660587099831, 'weight_model8': 0.6649132364024052}. Best is trial 26 with value: 0.791364969646788.
# [I 2024-04-09 00:22:26,150] Trial 45 finished with value: 0.7914685092933439 and parameters: {'weight_model0': 0.3985880465708296, 'weight_model1': 0.06396604654645438, 'weight_model2': 0.12152704976092257, 'weight_model3': 0.45406053280764214, 'weight_model4': 0.5818205229766468, 'weight_model5': 0.6194383827607007, 'weight_model6': 0.05403004705337873, 'weight_model7': 0.9476602387968629, 'weight_model8': 0.8617607438964193}. Best is trial 45 with value: 0.7914685092933439.
# [I 2024-04-09 00:22:26,309] Trial 46 finished with value: 0.7914193419747164 and parameters: {'weight_model0': 0.4167750130759063, 'weight_model1': 0.17801846620911266, 'weight_model2': 0.1185990099690021, 'weight_model3': 0.4800213237445057, 'weight_model4': 0.39038584209419436, 'weight_model5': 0.619337017156468, 'weight_model6': 0.03593484229933343, 'weight_model7': 0.7652275912750216, 'weight_model8': 0.8416499285948427}. Best is trial 45 with value: 0.7914685092933439.
# [I 2024-04-09 00:22:26,464] Trial 47 finished with value: 0.7915220007735445 and parameters: {'weight_model0': 0.38273018367606715, 'weight_model1': 0.007990423100741523, 'weight_model2': 0.02600297647858517, 'weight_model3': 0.47539828555543684, 'weight_model4': 0.4001100609480668, 'weight_model5': 0.5962266442767378, 'weight_model6': 0.23259282082532856, 'weight_model7': 0.9356248508738501, 'weight_model8': 0.8713326114232655}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:26,628] Trial 48 finished with value: 0.7915118309861411 and parameters: {'weight_model0': 0.5053758594657018, 'weight_model1': 0.013553033899082852, 'weight_model2': 0.0038014753550503905, 'weight_model3': 0.4691148703044575, 'weight_model4': 0.4683733231518044, 'weight_model5': 0.5819821199318812, 'weight_model6': 0.18394662563180236, 'weight_model7': 0.9564000753317112, 'weight_model8': 0.9060142235310162}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:26,793] Trial 49 finished with value: 0.791464265208837 and parameters: {'weight_model0': 0.5057774695165294, 'weight_model1': 0.003374825728011205, 'weight_model2': 0.006606311763064546, 'weight_model3': 0.2957745823784945, 'weight_model4': 0.40613966062758716, 'weight_model5': 0.5868359704217476, 'weight_model6': 0.20383904541661363, 'weight_model7': 0.8786994789581114, 'weight_model8': 0.9435931721073115}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:26,958] Trial 50 finished with value: 0.7913809850600217 and parameters: {'weight_model0': 0.5191894025593956, 'weight_model1': 0.004431505208046393, 'weight_model2': 0.02467469682343551, 'weight_model3': 0.2753053571220417, 'weight_model4': 0.4105907453512382, 'weight_model5': 0.5634588342190913, 'weight_model6': 0.23945903436668226, 'weight_model7': 0.7537582765962091, 'weight_model8': 0.9593932694647807}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,117] Trial 51 finished with value: 0.7914165392774005 and parameters: {'weight_model0': 0.5401345286172079, 'weight_model1': 0.00434372316370515, 'weight_model2': 0.001606734146240088, 'weight_model3': 0.26185290431086705, 'weight_model4': 0.38131110805040513, 'weight_model5': 0.5898439748838813, 'weight_model6': 0.21763190398171267, 'weight_model7': 0.7798978154310255, 'weight_model8': 0.959368193857395}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,275] Trial 52 finished with value: 0.7914197423600473 and parameters: {'weight_model0': 0.6165286486093151, 'weight_model1': 0.02933344863782542, 'weight_model2': 0.00347317819438063, 'weight_model3': 0.33617656701958487, 'weight_model4': 0.41945870966593257, 'weight_model5': 0.5996379186733248, 'weight_model6': 0.20168013414191333, 'weight_model7': 0.8152235502904297, 'weight_model8': 0.8827477790977241}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,433] Trial 53 finished with value: 0.7914050081798724 and parameters: {'weight_model0': 0.6136053755018335, 'weight_model1': 0.12029455605227032, 'weight_model2': 0.04706409977504475, 'weight_model3': 0.3477837499933412, 'weight_model4': 0.4237252683472506, 'weight_model5': 0.5075539707033602, 'weight_model6': 0.18415072546244554, 'weight_model7': 0.8761554402838502, 'weight_model8': 0.8732434452156173}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,596] Trial 54 finished with value: 0.791431914074105 and parameters: {'weight_model0': 0.46784659553637675, 'weight_model1': 0.027994966971502378, 'weight_model2': 0.04281750559578899, 'weight_model3': 0.3958706933648007, 'weight_model4': 0.35520323217536093, 'weight_model5': 0.6175836743016176, 'weight_model6': 0.25887006160657056, 'weight_model7': 0.8199159858254776, 'weight_model8': 0.9970382364431267}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,761] Trial 55 finished with value: 0.791410533497438 and parameters: {'weight_model0': 0.4750200838679496, 'weight_model1': 0.03443347375669868, 'weight_model2': 0.047990435268720696, 'weight_model3': 0.39762193938058543, 'weight_model4': 0.33348015838008743, 'weight_model5': 0.5441519414321632, 'weight_model6': 0.3260689467368465, 'weight_model7': 0.8294239748048038, 'weight_model8': 0.9982262199459695}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:27,928] Trial 56 finished with value: 0.7913793034416322 and parameters: {'weight_model0': 0.4889154983240394, 'weight_model1': 0.0355007101822711, 'weight_model2': 0.07048782037246912, 'weight_model3': 0.33138178978655913, 'weight_model4': 0.48505499790672946, 'weight_model5': 0.6180203533885028, 'weight_model6': 0.24501563635836596, 'weight_model7': 0.8780909970989592, 'weight_model8': 0.906336504418212}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,094] Trial 57 finished with value: 0.7913795436728307 and parameters: {'weight_model0': 0.39353267598450126, 'weight_model1': 0.034044447878183184, 'weight_model2': 0.019605830278859523, 'weight_model3': 0.21618029784363457, 'weight_model4': 0.4412612132821292, 'weight_model5': 0.4883736701108914, 'weight_model6': 0.25831004139886643, 'weight_model7': 0.9446856599793292, 'weight_model8': 0.9426781481732338}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,264] Trial 58 finished with value: 0.7914469685625446 and parameters: {'weight_model0': 0.5830266876232348, 'weight_model1': 0.10880433798425114, 'weight_model2': 0.0009701010666212911, 'weight_model3': 0.4386499144784862, 'weight_model4': 0.3379886546795101, 'weight_model5': 0.6619878296852932, 'weight_model6': 0.19621060592593353, 'weight_model7': 0.8242664476625567, 'weight_model8': 0.8681036665496633}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,427] Trial 59 finished with value: 0.7914217442867015 and parameters: {'weight_model0': 0.464551184477426, 'weight_model1': 0.1060579310857779, 'weight_model2': 0.10817363850523297, 'weight_model3': 0.44423366033170864, 'weight_model4': 0.3380816836187591, 'weight_model5': 0.6609378429172261, 'weight_model6': 0.31131571553475246, 'weight_model7': 0.9659899676584357, 'weight_model8': 0.9332027036749171}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,584] Trial 60 finished with value: 0.7913057126178233 and parameters: {'weight_model0': 0.4061196814998726, 'weight_model1': 0.14462438113463522, 'weight_model2': 0.06715418205045252, 'weight_model3': 0.38483772056660537, 'weight_model4': 0.49982082031668795, 'weight_model5': 0.5673746325263801, 'weight_model6': 0.2657733106395336, 'weight_model7': 0.8542704371458787, 'weight_model8': 0.8641067510124576}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,748] Trial 61 finished with value: 0.7914125354240922 and parameters: {'weight_model0': 0.4844881173974226, 'weight_model1': 0.0979677850714933, 'weight_model2': 0.09105677414820612, 'weight_model3': 0.41716552216669345, 'weight_model4': 0.3313516825023785, 'weight_model5': 0.6583937990211044, 'weight_model6': 0.3236319849923628, 'weight_model7': 0.9608707080910446, 'weight_model8': 0.9294432426515057}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:28,913] Trial 62 finished with value: 0.7914691499098733 and parameters: {'weight_model0': 0.5693478889347611, 'weight_model1': 0.10856396777812308, 'weight_model2': 0.11127570150005095, 'weight_model3': 0.43516473067669675, 'weight_model4': 0.2946668065505559, 'weight_model5': 0.6482801528578209, 'weight_model6': 0.19512453790297157, 'weight_model7': 0.9108243169444021, 'weight_model8': 0.9741695286681263}. Best is trial 47 with value: 0.7915220007735445.
# [I 2024-04-09 00:22:29,075] Trial 63 finished with value: 0.7915575549909233 and parameters: {'weight_model0': 0.5867188741428564, 'weight_model1': 0.05049118075792673, 'weight_model2': 0.0785428580970898, 'weight_model3': 0.5206527341656366, 'weight_model4': 0.24411074884957984, 'weight_model5': 0.5222466790561823, 'weight_model6': 0.20732508680887513, 'weight_model7': 0.9049809389285777, 'weight_model8': 0.9807826947898622}. Best is trial 63 with value: 0.7915575549909233.
# [I 2024-04-09 00:22:29,242] Trial 64 finished with value: 0.7915581956074527 and parameters: {'weight_model0': 0.5643668943284093, 'weight_model1': 0.05658158512042174, 'weight_model2': 0.02733870025931326, 'weight_model3': 0.5305996162093622, 'weight_model4': 0.27724209680568634, 'weight_model5': 0.5248680367031493, 'weight_model6': 0.2106333406257619, 'weight_model7': 0.9113151111090768, 'weight_model8': 0.9640683153018568}. Best is trial 64 with value: 0.7915581956074527.
# [I 2024-04-09 00:22:29,406] Trial 65 finished with value: 0.7915633205396874 and parameters: {'weight_model0': 0.6513018877788623, 'weight_model1': 0.05851398985858067, 'weight_model2': 0.11370679862803283, 'weight_model3': 0.5264016765785109, 'weight_model4': 0.28576607167592716, 'weight_model5': 0.4514039286821865, 'weight_model6': 0.14316305741571875, 'weight_model7': 0.9090206787685744, 'weight_model8': 0.9732707034758985}. Best is trial 65 with value: 0.7915633205396874.
# [I 2024-04-09 00:22:29,572] Trial 66 finished with value: 0.7915795761841196 and parameters: {'weight_model0': 0.6726869514038016, 'weight_model1': 0.06356522630972351, 'weight_model2': 0.12158802040698397, 'weight_model3': 0.5317644753721134, 'weight_model4': 0.22764024634649072, 'weight_model5': 0.42986270412754657, 'weight_model6': 0.15314048203610148, 'weight_model7': 0.9069056866253373, 'weight_model8': 0.9707483336313801}. Best is trial 66 with value: 0.7915795761841196.
# [I 2024-04-09 00:22:29,738] Trial 67 finished with value: 0.7916113667793885 and parameters: {'weight_model0': 0.6552983663254341, 'weight_model1': 0.05491732040881789, 'weight_model2': 0.09453421051036598, 'weight_model3': 0.5209087301711527, 'weight_model4': 0.22379513175222196, 'weight_model5': 0.46034757284970074, 'weight_model6': 0.13416137216817725, 'weight_model7': 0.9119548258300361, 'weight_model8': 0.9701675711648065}. Best is trial 67 with value: 0.7916113667793885.
# [I 2024-04-09 00:22:29,903] Trial 68 finished with value: 0.7916239388787769 and parameters: {'weight_model0': 0.65860811264831, 'weight_model1': 0.06419571494874685, 'weight_model2': 0.07862557161511746, 'weight_model3': 0.5302589849446429, 'weight_model4': 0.21686193935005044, 'weight_model5': 0.44896510547261365, 'weight_model6': 0.1432501881485581, 'weight_model7': 0.9605156911919913, 'weight_model8': 0.9053289940868638}. Best is trial 68 with value: 0.7916239388787769.
# [I 2024-04-09 00:22:30,063] Trial 69 finished with value: 0.7916279427320854 and parameters: {'weight_model0': 0.6591830834569982, 'weight_model1': 0.0524531541525602, 'weight_model2': 0.07644155136074712, 'weight_model3': 0.542183570207262, 'weight_model4': 0.19586755946606577, 'weight_model5': 0.44793257923761887, 'weight_model6': 0.14982633316656305, 'weight_model7': 0.9042496188302617, 'weight_model8': 0.9694308032080371}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:30,237] Trial 70 finished with value: 0.791564121310349 and parameters: {'weight_model0': 0.6543123170666245, 'weight_model1': 0.14570437784233117, 'weight_model2': 0.14173619368611423, 'weight_model3': 0.5321805780028274, 'weight_model4': 0.19522118815043996, 'weight_model5': 0.44215545091654307, 'weight_model6': 0.12706064862153335, 'weight_model7': 0.9991016943832567, 'weight_model8': 0.9704240372895345}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:30,404] Trial 71 finished with value: 0.7915926287459051 and parameters: {'weight_model0': 0.6709181204929084, 'weight_model1': 0.05522124005525976, 'weight_model2': 0.14365344556181983, 'weight_model3': 0.5416714299132385, 'weight_model4': 0.19729798581921215, 'weight_model5': 0.46624483333768646, 'weight_model6': 0.13851634188801984, 'weight_model7': 0.9005965925383165, 'weight_model8': 0.9701175033019757}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:30,565] Trial 72 finished with value: 0.7915650822351431 and parameters: {'weight_model0': 0.6696458741338454, 'weight_model1': 0.14106038382128325, 'weight_model2': 0.1490603499472141, 'weight_model3': 0.5401854690846495, 'weight_model4': 0.19509093519878373, 'weight_model5': 0.4465921515985031, 'weight_model6': 0.12587677036029493, 'weight_model7': 0.9972885272839698, 'weight_model8': 0.9571591759750153}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:30,729] Trial 73 finished with value: 0.7915646017727461 and parameters: {'weight_model0': 0.6753444152472861, 'weight_model1': 0.14157159648606016, 'weight_model2': 0.154535910371486, 'weight_model3': 0.5557269047641358, 'weight_model4': 0.19077548049703594, 'weight_model5': 0.4471206773847946, 'weight_model6': 0.13771017469793148, 'weight_model7': 0.9970547368775625, 'weight_model8': 0.9592557796117832}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:30,892] Trial 74 finished with value: 0.7915770137180022 and parameters: {'weight_model0': 0.6992321100365921, 'weight_model1': 0.13221828315489645, 'weight_model2': 0.15155014166011066, 'weight_model3': 0.5768511049640104, 'weight_model4': 0.189215936989446, 'weight_model5': 0.44719094007280374, 'weight_model6': 0.11057826929612621, 'weight_model7': 0.9988394937923458, 'weight_model8': 0.9480345241521437}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:31,082] Trial 75 finished with value: 0.7914456072524197 and parameters: {'weight_model0': 0.7310035639068696, 'weight_model1': 0.23871836160911464, 'weight_model2': 0.15386444710010905, 'weight_model3': 0.5626905647666741, 'weight_model4': 0.18536248144237305, 'weight_model5': 0.3983421352889346, 'weight_model6': 0.09608837499215338, 'weight_model7': 0.9666584571147671, 'weight_model8': 0.9321041349630186}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:31,301] Trial 76 finished with value: 0.7915309694049554 and parameters: {'weight_model0': 0.7100135106809232, 'weight_model1': 0.19417580225055253, 'weight_model2': 0.14063497696751456, 'weight_model3': 0.5858884803447468, 'weight_model4': 0.13062023818179197, 'weight_model5': 0.3921528520892956, 'weight_model6': 0.10506418485080335, 'weight_model7': 0.979117128596824, 'weight_model8': 0.9995779345162761}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:31,463] Trial 77 finished with value: 0.7914855657084378 and parameters: {'weight_model0': 0.7469078853185656, 'weight_model1': 0.14148398989429223, 'weight_model2': 0.227945343142779, 'weight_model3': 0.6093053355846282, 'weight_model4': 0.21804436361483812, 'weight_model5': 0.4686030300593508, 'weight_model6': 0.1473323760121108, 'weight_model7': 0.9994989784689018, 'weight_model8': 0.9089600831367879}. Best is trial 69 with value: 0.7916279427320854.
# [I 2024-04-09 00:22:31,630] Trial 78 finished with value: 0.7916445186847823 and parameters: {'weight_model0': 0.6797759427494022, 'weight_model1': 0.09341739322788736, 'weight_model2': 0.09074529746863491, 'weight_model3': 0.49799883879454476, 'weight_model4': 0.13246384308116843, 'weight_model5': 0.41847300679409055, 'weight_model6': 0.10157928133660357, 'weight_model7': 0.9408474857647864, 'weight_model8': 0.9430843986245053}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:31,795] Trial 79 finished with value: 0.7915891053549936 and parameters: {'weight_model0': 0.781388987767971, 'weight_model1': 0.09129356244717585, 'weight_model2': 0.08337587530937508, 'weight_model3': 0.4928903290470334, 'weight_model4': 0.13154952612704285, 'weight_model5': 0.34668018048996263, 'weight_model6': 0.1061219936442451, 'weight_model7': 0.8708540150046782, 'weight_model8': 0.8997577438084263}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:31,962] Trial 80 finished with value: 0.7915991149882647 and parameters: {'weight_model0': 0.7589955745878407, 'weight_model1': 0.08954472106776562, 'weight_model2': 0.09433583332445837, 'weight_model3': 0.49896324197927383, 'weight_model4': 0.13045642221330103, 'weight_model5': 0.3571360795780496, 'weight_model6': 0.09775563636192464, 'weight_model7': 0.8805827657688182, 'weight_model8': 0.8948758444768342}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,129] Trial 81 finished with value: 0.7916048004599626 and parameters: {'weight_model0': 0.7452536491473298, 'weight_model1': 0.09237236241601252, 'weight_model2': 0.0846630597779056, 'weight_model3': 0.49749925784931104, 'weight_model4': 0.12373991626252519, 'weight_model5': 0.357182768064049, 'weight_model6': 0.10307347333844744, 'weight_model7': 0.8754727388844382, 'weight_model8': 0.8985610127900205}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,294] Trial 82 finished with value: 0.7916162514804248 and parameters: {'weight_model0': 0.768602450907209, 'weight_model1': 0.08624100217407216, 'weight_model2': 0.07637536030130909, 'weight_model3': 0.49946024619648066, 'weight_model4': 0.10316463823002704, 'weight_model5': 0.3484590314688571, 'weight_model6': 0.09902187903816428, 'weight_model7': 0.8611820439982104, 'weight_model8': 0.8894741015723597}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,455] Trial 83 finished with value: 0.7916065621554184 and parameters: {'weight_model0': 0.7763951047927258, 'weight_model1': 0.09423069827156567, 'weight_model2': 0.07779097503443673, 'weight_model3': 0.48482855487875026, 'weight_model4': 0.08044406360537726, 'weight_model5': 0.3458224382164756, 'weight_model6': 0.10165271393965553, 'weight_model7': 0.8634895860032201, 'weight_model8': 0.9020265961049508}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,616] Trial 84 finished with value: 0.7916293841192764 and parameters: {'weight_model0': 0.7732684673221596, 'weight_model1': 0.0934430888012368, 'weight_model2': 0.058314549592354284, 'weight_model3': 0.4813541725304743, 'weight_model4': 0.03480277151856855, 'weight_model5': 0.3261280402843763, 'weight_model6': 0.08182376877196881, 'weight_model7': 0.8454875847921921, 'weight_model8': 0.8484606258031514}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,775] Trial 85 finished with value: 0.7916056012306244 and parameters: {'weight_model0': 0.7849707673392758, 'weight_model1': 0.09162172839374416, 'weight_model2': 0.07788605476172772, 'weight_model3': 0.49488062955073847, 'weight_model4': 0.03664851973004622, 'weight_model5': 0.3342119133383612, 'weight_model6': 0.0801026448506223, 'weight_model7': 0.841473412373609, 'weight_model8': 0.8417953498714631}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:32,934] Trial 86 finished with value: 0.7916359504387022 and parameters: {'weight_model0': 0.8376313848763293, 'weight_model1': 0.08710465644443613, 'weight_model2': 0.07021282093777331, 'weight_model3': 0.5055162130897234, 'weight_model4': 0.016304199749675452, 'weight_model5': 0.31908220540215976, 'weight_model6': 0.038196430998558406, 'weight_model7': 0.8449278604639436, 'weight_model8': 0.8890086951706088}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:33,097] Trial 87 finished with value: 0.7915580354533203 and parameters: {'weight_model0': 0.8113372445250655, 'weight_model1': 0.16614398411760795, 'weight_model2': 0.05549274223780447, 'weight_model3': 0.48850763440884326, 'weight_model4': 0.010093911368590183, 'weight_model5': 0.3144040718024219, 'weight_model6': 0.025086710016790165, 'weight_model7': 0.8401769515053221, 'weight_model8': 0.8384898510226176}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:33,281] Trial 88 finished with value: 0.7915919881293757 and parameters: {'weight_model0': 0.8612787416429462, 'weight_model1': 0.11511244210008689, 'weight_model2': 0.05022445092681099, 'weight_model3': 0.46591968943939227, 'weight_model4': 0.05961238759585881, 'weight_model5': 0.29365974371711984, 'weight_model6': 0.04409011859104194, 'weight_model7': 0.842318976435876, 'weight_model8': 0.8476039060429258}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:33,437] Trial 89 finished with value: 0.791500379965679 and parameters: {'weight_model0': 0.8173824498952056, 'weight_model1': 0.19126663254427645, 'weight_model2': 0.06674220251609157, 'weight_model3': 0.5113178295686259, 'weight_model4': 0.002295347049062424, 'weight_model5': 0.41991295878667523, 'weight_model6': 0.07954468144502942, 'weight_model7': 0.785509663669444, 'weight_model8': 0.9224738254896111}. Best is trial 78 with value: 0.7916445186847823.
# [I 2024-04-09 00:22:33,595] Trial 90 finished with value: 0.7917103420331727 and parameters: {'weight_model0': 0.7793703920796822, 'weight_model1': 0.08077750232562561, 'weight_model2': 0.0324557093134007, 'weight_model3': 0.5762254601386839, 'weight_model4': 0.0705094731106985, 'weight_model5': 0.2759455291299427, 'weight_model6': 0.05994885375518048, 'weight_model7': 0.9403640426114301, 'weight_model8': 0.8189518141495358}. Best is trial 90 with value: 0.7917103420331727.
# [I 2024-04-09 00:22:33,757] Trial 91 finished with value: 0.7916932856180788 and parameters: {'weight_model0': 0.7735414635741141, 'weight_model1': 0.08394594249544081, 'weight_model2': 0.04533735704453129, 'weight_model3': 0.5707029640675526, 'weight_model4': 0.06477393007595172, 'weight_model5': 0.2797509439297824, 'weight_model6': 0.06575813958259898, 'weight_model7': 0.934414093529968, 'weight_model8': 0.8000473153489206}. Best is trial 90 with value: 0.7917103420331727.
# [I 2024-04-09 00:22:33,915] Trial 92 finished with value: 0.7916495635399509 and parameters: {'weight_model0': 0.8912522184386887, 'weight_model1': 0.0752792035629414, 'weight_model2': 0.034269559687902816, 'weight_model3': 0.5706892296454674, 'weight_model4': 0.09801956881418511, 'weight_model5': 0.26771080506897865, 'weight_model6': 0.05496044797293838, 'weight_model7': 0.9329733155668007, 'weight_model8': 0.819293082719886}. Best is trial 90 with value: 0.7917103420331727.
# [I 2024-04-09 00:22:34,070] Trial 93 finished with value: 0.791698090242049 and parameters: {'weight_model0': 0.8743037095112797, 'weight_model1': 0.04019779861047317, 'weight_model2': 0.03315059080307147, 'weight_model3': 0.5683931034351041, 'weight_model4': 0.09617758531525306, 'weight_model5': 0.2700294130450246, 'weight_model6': 0.039312086204862415, 'weight_model7': 0.9440215500706296, 'weight_model8': 0.8163032514758294}. Best is trial 90 with value: 0.7917103420331727.
# [I 2024-04-09 00:22:34,234] Trial 94 finished with value: 0.7916823150600137 and parameters: {'weight_model0': 0.8949532542668391, 'weight_model1': 0.028235621163918964, 'weight_model2': 0.03944337359513835, 'weight_model3': 0.6122616588532931, 'weight_model4': 0.08854263683426228, 'weight_model5': 0.25080765363169605, 'weight_model6': 0.05774654938560876, 'weight_model7': 0.9364069420705876, 'weight_model8': 0.7987849422701145}. Best is trial 90 with value: 0.7917103420331727.
# [I 2024-04-09 00:22:34,391] Trial 95 finished with value: 0.7917318026869059 and parameters: {'weight_model0': 0.9049030407405751, 'weight_model1': 0.019546653554336463, 'weight_model2': 0.02861713096999626, 'weight_model3': 0.6100633852445709, 'weight_model4': 0.0529293966011085, 'weight_model5': 0.26349378890008135, 'weight_model6': 0.03216511646002168, 'weight_model7': 0.94630428298786, 'weight_model8': 0.8176240564944938}. Best is trial 95 with value: 0.7917318026869059.
# [I 2024-04-09 00:22:34,546] Trial 96 finished with value: 0.7916989710897768 and parameters: {'weight_model0': 0.9133190151828188, 'weight_model1': 0.03226654005341931, 'weight_model2': 0.030246093325398432, 'weight_model3': 0.6621708625379827, 'weight_model4': 0.047321482349014815, 'weight_model5': 0.2412905081818129, 'weight_model6': 0.024766192428870886, 'weight_model7': 0.9323557257522705, 'weight_model8': 0.7849908481654824}. Best is trial 95 with value: 0.7917318026869059.
# [I 2024-04-09 00:22:34,700] Trial 97 finished with value: 0.7916961683924609 and parameters: {'weight_model0': 0.9194942681277144, 'weight_model1': 0.026821147126624936, 'weight_model2': 0.050160626961163635, 'weight_model3': 0.6653373757007623, 'weight_model4': 0.04517923617448499, 'weight_model5': 0.25812958373280637, 'weight_model6': 0.03290907059479018, 'weight_model7': 0.9500225865739598, 'weight_model8': 0.8162661765650439}. Best is trial 95 with value: 0.7917318026869059.
# [I 2024-04-09 00:22:34,858] Trial 98 finished with value: 0.7917101018019742 and parameters: {'weight_model0': 0.9176869595991329, 'weight_model1': 0.025538750525299768, 'weight_model2': 0.030968615728536472, 'weight_model3': 0.6618923108898557, 'weight_model4': 0.0788636747891808, 'weight_model5': 0.24975879005776472, 'weight_model6': 0.022880091856807727, 'weight_model7': 0.9380282864178368, 'weight_model8': 0.8046442090429418}. Best is trial 95 with value: 0.7917318026869059.
# ...
# [I 2024-04-09 00:33:11,724] Trial 2968 finished with value: 0.7909596195378432 and parameters: {'weight_model0': 0.650824927774439, 'weight_model1': 0.09325604354721154, 'weight_model2': 0.5541402932014605, 'weight_model3': 0.43244105917322534, 'weight_model4': 0.3387581761681152, 'weight_model5': 0.5875388635059202, 'weight_model6': 0.047268936285946014, 'weight_model7': 0.7285608328602604, 'weight_model8': 0.08813168852970872}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:11,994] Trial 2969 finished with value: 0.7908526365774421 and parameters: {'weight_model0': 0.9511550923972915, 'weight_model1': 0.5071691233484674, 'weight_model2': 0.10538986814536414, 'weight_model3': 0.46184057385446536, 'weight_model4': 0.046634850995945464, 'weight_model5': 0.8234392317118927, 'weight_model6': 0.6370011375893543, 'weight_model7': 0.6744627846340978, 'weight_model8': 0.37710533079498887}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:12,265] Trial 2970 finished with value: 0.7910565127879071 and parameters: {'weight_model0': 0.5564890631394134, 'weight_model1': 0.24076771583597953, 'weight_model2': 0.4172700746886684, 'weight_model3': 0.37337063174336393, 'weight_model4': 0.0002891656927698494, 'weight_model5': 0.5944723064973078, 'weight_model6': 0.7194214532422301, 'weight_model7': 0.9210733255061166, 'weight_model8': 0.2899444151628204}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:12,547] Trial 2971 finished with value: 0.7914066097211957 and parameters: {'weight_model0': 0.037321552533698496, 'weight_model1': 0.06545893741058667, 'weight_model2': 0.14038072767118606, 'weight_model3': 0.33644400614362713, 'weight_model4': 0.03280450729248829, 'weight_model5': 0.1598061480906498, 'weight_model6': 0.3641458509243423, 'weight_model7': 0.6117413226243524, 'weight_model8': 0.4865824251671875}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:12,816] Trial 2972 finished with value: 0.7913656903403836 and parameters: {'weight_model0': 0.9479205819987386, 'weight_model1': 0.034564719319480526, 'weight_model2': 0.22910356301731016, 'weight_model3': 0.42116167494693546, 'weight_model4': 0.29271629377372294, 'weight_model5': 0.43093083419236455, 'weight_model6': 0.017773101221276087, 'weight_model7': 0.9818592326321598, 'weight_model8': 0.22762651114465532}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:13,084] Trial 2973 finished with value: 0.7908724156127858 and parameters: {'weight_model0': 0.0816996727189109, 'weight_model1': 0.1276859038862359, 'weight_model2': 0.6176754920278104, 'weight_model3': 0.40110656205776457, 'weight_model4': 0.057891807877416164, 'weight_model5': 0.43800187785833594, 'weight_model6': 0.5290682212006323, 'weight_model7': 0.547206888352539, 'weight_model8': 0.3451962905687507}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:13,370] Trial 2974 finished with value: 0.7909700295564451 and parameters: {'weight_model0': 0.8095008568755344, 'weight_model1': 0.08090595512789107, 'weight_model2': 0.5967789472212973, 'weight_model3': 0.4397814527842919, 'weight_model4': 0.8308050177075417, 'weight_model5': 0.29191035246253894, 'weight_model6': 0.03383725264577785, 'weight_model7': 0.9494156548479451, 'weight_model8': 0.31058096455303785}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:13,640] Trial 2975 finished with value: 0.78971658323971 and parameters: {'weight_model0': 0.01884187180229762, 'weight_model1': 0.5360567430400998, 'weight_model2': 0.83031583492653, 'weight_model3': 0.48128544496519904, 'weight_model4': 0.5915438467570541, 'weight_model5': 0.1401135780819041, 'weight_model6': 0.5543291350143323, 'weight_model7': 0.010599295364798977, 'weight_model8': 0.27558890748043063}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:13,911] Trial 2976 finished with value: 0.790925746938854 and parameters: {'weight_model0': 0.05320069484590534, 'weight_model1': 0.40525956879114133, 'weight_model2': 0.387059655227344, 'weight_model3': 0.20582331117058106, 'weight_model4': 0.6946983872450458, 'weight_model5': 0.20390322072325426, 'weight_model6': 0.017236270816556064, 'weight_model7': 0.9620756545755059, 'weight_model8': 0.3930461280987094}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:14,184] Trial 2977 finished with value: 0.7907093787060667 and parameters: {'weight_model0': 0.3339647352300167, 'weight_model1': 0.2664628264704991, 'weight_model2': 0.058915609623627234, 'weight_model3': 0.35945982190156284, 'weight_model4': 0.21969331630384248, 'weight_model5': 0.24979992221456906, 'weight_model6': 0.8508792422180558, 'weight_model7': 0.5077892935286953, 'weight_model8': 0.3655429031479846}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:14,467] Trial 2978 finished with value: 0.7902724782330515 and parameters: {'weight_model0': 0.870379265656862, 'weight_model1': 0.05826053264852758, 'weight_model2': 0.25327399561244773, 'weight_model3': 0.4148136259279173, 'weight_model4': 0.8742666373837941, 'weight_model5': 0.17549434689324944, 'weight_model6': 0.6896668453603034, 'weight_model7': 0.10451325004506673, 'weight_model8': 0.32404799978311205}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:14,739] Trial 2979 finished with value: 0.7907701571992886 and parameters: {'weight_model0': 0.019141767331132906, 'weight_model1': 0.7622308075435078, 'weight_model2': 0.5111747962613219, 'weight_model3': 0.4634619072310481, 'weight_model4': 0.080498592101821, 'weight_model5': 0.498485305524808, 'weight_model6': 0.03836492364497963, 'weight_model7': 0.9390396515112186, 'weight_model8': 0.5098954745493465}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:15,015] Trial 2980 finished with value: 0.7911627750547127 and parameters: {'weight_model0': 0.04698278264381112, 'weight_model1': 0.17499783731352841, 'weight_model2': 0.4480480761159664, 'weight_model3': 0.44231436267070984, 'weight_model4': 0.01791439035914875, 'weight_model5': 0.1912726877695232, 'weight_model6': 0.24442005113352305, 'weight_model7': 0.9009031921145546, 'weight_model8': 0.17413789641871885}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:15,285] Trial 2981 finished with value: 0.7909609808479681 and parameters: {'weight_model0': 0.10618644212460847, 'weight_model1': 0.10940105129394145, 'weight_model2': 0.33580026651659833, 'weight_model3': 0.7951099737950252, 'weight_model4': 0.9330166563417783, 'weight_model5': 0.016191759887304952, 'weight_model6': 0.5731819053443351, 'weight_model7': 0.9791740781286014, 'weight_model8': 0.546882745233046}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:15,573] Trial 2982 finished with value: 0.7913993227081744 and parameters: {'weight_model0': 0.43191265603868473, 'weight_model1': 0.03622414726747202, 'weight_model2': 0.0937866409799011, 'weight_model3': 0.38653974820154624, 'weight_model4': 0.40380788505866266, 'weight_model5': 0.8118272392855288, 'weight_model6': 0.018904417862713345, 'weight_model7': 0.5966594427781501, 'weight_model8': 0.9482659090014453}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:15,880] Trial 2983 finished with value: 0.7900784515017253 and parameters: {'weight_model0': 0.06483903686966386, 'weight_model1': 0.7022064201925805, 'weight_model2': 0.8994352730284407, 'weight_model3': 0.32409697935556053, 'weight_model4': 0.036828069121860166, 'weight_model5': 0.12162386066707956, 'weight_model6': 0.7480438407376158, 'weight_model7': 0.6547507733348061, 'weight_model8': 0.2472752209492462}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:16,158] Trial 2984 finished with value: 0.7902739196202425 and parameters: {'weight_model0': 7.257967414172912e-05, 'weight_model1': 0.45012664213491443, 'weight_model2': 0.1195620127928016, 'weight_model3': 0.42048789175594387, 'weight_model4': 0.00013774240318584902, 'weight_model5': 0.26279628510964287, 'weight_model6': 0.18887649792202088, 'weight_model7': 0.30466960962141976, 'weight_model8': 0.017842910318522254}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:16,434] Trial 2985 finished with value: 0.7913638485678617 and parameters: {'weight_model0': 0.3603977155332846, 'weight_model1': 0.07278544459549947, 'weight_model2': 0.06296812391405275, 'weight_model3': 0.40158335505645487, 'weight_model4': 0.5404208999353707, 'weight_model5': 0.9883470206252819, 'weight_model6': 0.1421414327145895, 'weight_model7': 0.9260790846523835, 'weight_model8': 0.29862474266886635}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:16,711] Trial 2986 finished with value: 0.7913234096494466 and parameters: {'weight_model0': 0.030900693008924902, 'weight_model1': 0.19369968237799304, 'weight_model2': 0.08159912334675394, 'weight_model3': 0.11357334265050045, 'weight_model4': 0.058114461226236286, 'weight_model5': 0.22906270078283889, 'weight_model6': 0.35025923153020133, 'weight_model7': 0.9545857510548235, 'weight_model8': 0.9709096156035998}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:16,982] Trial 2987 finished with value: 0.7916717448872795 and parameters: {'weight_model0': 0.019826845314048946, 'weight_model1': 0.05292508995582454, 'weight_model2': 0.1035776687769355, 'weight_model3': 0.8999592567926341, 'weight_model4': 0.4373251909745448, 'weight_model5': 0.4076423250774274, 'weight_model6': 0.05135468044984881, 'weight_model7': 0.9992965326014742, 'weight_model8': 0.4099019285125965}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:17,256] Trial 2988 finished with value: 0.7907409290701372 and parameters: {'weight_model0': 0.08539133919807904, 'weight_model1': 0.9378790401867891, 'weight_model2': 0.14348113920537103, 'weight_model3': 0.46153053291217816, 'weight_model4': 0.30173587596917517, 'weight_model5': 0.9998276948286909, 'weight_model6': 0.051049433492833626, 'weight_model7': 0.9125520038851355, 'weight_model8': 0.2721208911919218}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:17,534] Trial 2989 finished with value: 0.7905754097743668 and parameters: {'weight_model0': 0.6803878525245588, 'weight_model1': 0.16376048200071258, 'weight_model2': 0.060186426438702256, 'weight_model3': 0.4385804835975032, 'weight_model4': 0.0330208495861551, 'weight_model5': 0.1530666730057395, 'weight_model6': 0.31314746182210246, 'weight_model7': 0.07023267424183943, 'weight_model8': 0.4457578969936998}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:17,811] Trial 2990 finished with value: 0.7911116858864972 and parameters: {'weight_model0': 0.04678180608100467, 'weight_model1': 0.2520960499353419, 'weight_model2': 0.3106353655657563, 'weight_model3': 0.9650189672352895, 'weight_model4': 0.896350954153569, 'weight_model5': 0.16638396041837075, 'weight_model6': 0.03355094351338837, 'weight_model7': 0.9815371942364044, 'weight_model8': 0.34928490602907514}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:18,087] Trial 2991 finished with value: 0.7904446439253138 and parameters: {'weight_model0': 0.0003610460727880105, 'weight_model1': 0.0871250023235234, 'weight_model2': 0.6805680472714869, 'weight_model3': 0.382507039418691, 'weight_model4': 0.018241124987148596, 'weight_model5': 0.20008617706284773, 'weight_model6': 0.334678862555958, 'weight_model7': 0.21620024831630535, 'weight_model8': 0.32362651309619184}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:18,367] Trial 2992 finished with value: 0.7910694852726263 and parameters: {'weight_model0': 0.03191362084745735, 'weight_model1': 0.4184674434386659, 'weight_model2': 0.46626560689586694, 'weight_model3': 0.41269862670637536, 'weight_model4': 0.6119713825021954, 'weight_model5': 0.9760751747217238, 'weight_model6': 0.0005025360783366664, 'weight_model7': 0.9381567533844355, 'weight_model8': 0.46278165358027046}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:18,635] Trial 2993 finished with value: 0.7912791270318554 and parameters: {'weight_model0': 0.00021383153272812316, 'weight_model1': 0.03873336330653292, 'weight_model2': 0.2738982663360401, 'weight_model3': 0.18919101541404937, 'weight_model4': 0.6368318024834311, 'weight_model5': 0.13816004363757942, 'weight_model6': 0.01725080099695467, 'weight_model7': 0.9636992228415384, 'weight_model8': 0.29597911218501904}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:18,905] Trial 2994 finished with value: 0.7908842670185787 and parameters: {'weight_model0': 0.470595390936351, 'weight_model1': 0.6735422613630354, 'weight_model2': 0.11768006896726262, 'weight_model3': 0.8843780636959203, 'weight_model4': 0.0780649420955129, 'weight_model5': 0.5415351875326867, 'weight_model6': 0.0529780859916264, 'weight_model7': 0.8947356038442993, 'weight_model8': 0.1475325492615922}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:19,179] Trial 2995 finished with value: 0.7910784539040372 and parameters: {'weight_model0': 0.5078473445341655, 'weight_model1': 0.12467426325100558, 'weight_model2': 0.1686678294578237, 'weight_model3': 0.48206247531710167, 'weight_model4': 0.04981336215949278, 'weight_model5': 0.7134997918922231, 'weight_model6': 0.9334226716281253, 'weight_model7': 0.7490577810225866, 'weight_model8': 0.26416022091383407}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:19,454] Trial 2996 finished with value: 0.7906855157403485 and parameters: {'weight_model0': 0.07031815551819437, 'weight_model1': 0.44200307103829867, 'weight_model2': 0.6481542880266902, 'weight_model3': 0.3577474225885052, 'weight_model4': 0.376334941119498, 'weight_model5': 0.920620292089592, 'weight_model6': 0.018325926876678132, 'weight_model7': 0.4830629191625332, 'weight_model8': 0.33599207365476674}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:19,734] Trial 2997 finished with value: 0.7899080475049187 and parameters: {'weight_model0': 0.01801041268642341, 'weight_model1': 0.7377898674167895, 'weight_model2': 0.7424116705715953, 'weight_model3': 0.43087728153245075, 'weight_model4': 0.5632204557703797, 'weight_model5': 0.17983851071627238, 'weight_model6': 0.0004076335310535051, 'weight_model7': 0.40256258546033313, 'weight_model8': 0.21919100448648005}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:20,018] Trial 2998 finished with value: 0.7906405124291618 and parameters: {'weight_model0': 0.5152336797891357, 'weight_model1': 0.3926859341324752, 'weight_model2': 0.08416991957838187, 'weight_model3': 0.0025818032775400956, 'weight_model4': 0.9641410095883313, 'weight_model5': 0.22064701317725896, 'weight_model6': 0.4953223410970445, 'weight_model7': 0.9484277824561755, 'weight_model8': 0.3120257968384814}. Best is trial 2223 with value: 0.7920867042441646.
# [I 2024-04-09 00:33:20,294] Trial 2999 finished with value: 0.7918885935824638 and parameters: {'weight_model0': 0.04868731959743844, 'weight_model1': 0.0695661462332304, 'weight_model2': 0.09885309432463098, 'weight_model3': 0.8793184626388818, 'weight_model4': 0.01888536632576052, 'weight_model5': 0.6563271963661254, 'weight_model6': 0.03442501285531805, 'weight_model7': 0.9212071542755824, 'weight_model8': 0.3682741383023852}. Best is trial 2223 with value: 0.7920867042441646.

# %%
weights = list(best_weights.values())
weights
# Out:
# [0.05691356649453222,
#  0.01869011710038887,
#  0.05760203363004765,
#  0.4059237663923347,
#  0.03555506070606728,
#  0.22473946451953958,
#  0.0008350492754695127,
#  0.982611784076993,
#  0.35421913240010755]

# %%
# Рассчитайте ROC-кривую
fpr, tpr, thresholds = roc_curve(y_test, np.average(predictions, axis=0, weights=weights))

# Вычислите площадь под ROC-кривой (ROC AUC)
roc_auc = roc_auc_score(y_test, np.average(predictions, axis=0, weights=weights))

# Нарисуйте ROC-кривую
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Найдите порог, максимизирующий чувствительность и минимизирующий ложноположительные результаты
best_threshold_idx = np.argmax(tpr - fpr)
best_threshold = thresholds[best_threshold_idx]
best_tpr = tpr[best_threshold_idx]
best_fpr = fpr[best_threshold_idx]

print("Best Threshold:", best_threshold)
print("Sensitivity (True Positive Rate) at best threshold:", best_tpr)
print("False Positive Rate at best threshold:", best_fpr)
# Out:
# Best Threshold: 0.07885470683972697
# Sensitivity (True Positive Rate) at best threshold: 0.7373831775700934
# False Positive Rate at best threshold: 0.29594721960414705

# %%
# Вычислите значение Youden's J statistic для каждого порога
youden_j = tpr - fpr

# Найдите порог, максимизирующий значение Youden's J statistic
best_threshold_idx = np.argmax(youden_j)
best_threshold = thresholds[best_threshold_idx]
best_tpr = tpr[best_threshold_idx]
best_fpr = fpr[best_threshold_idx]

print("Best Threshold:", best_threshold)
print("Sensitivity (True Positive Rate) at best threshold:", best_tpr)
print("False Positive Rate at best threshold:", best_fpr)
# Out:
# Best Threshold: 0.07885470683972697
# Sensitivity (True Positive Rate) at best threshold: 0.7373831775700934
# False Positive Rate at best threshold: 0.29594721960414705

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,\
                        test_size = 0.20, random_state = 142, stratify=y)
# print(x_train.shape)
# x_concat = []
# y_concat = []
# for i in tqdm(range(35)):
#     x_x = x_train.loc[y_train[y_train == 1]]
#     y_x = y_train[y_train == 1]
#     x_concat.append(x_x)
#     y_concat.append(y_x)


# x_train = pd.concat([x_train] + x_concat)
# y_train = pd.concat([y_train] + y_concat)
# x_train.index = range(x_train.shape[0])
# y_train.index = range(x_train.shape[0])
# x_train = x_train.sample(frac=1)
# y_train = y_train.loc[x_train.index]
# x_train.index = range(x_train.shape[0])
# y_train.index = range(x_train.shape[0])
                    
# X = pd.concat([x_train, x_test])
# y = pd.concat([y_train, y_test])

# X.index = range(X.shape[0])
# y.index = range(X.shape[0])

# print(x_train.shape[0], y_train.shape[0])

# %%
# Обучение моделей на всей выборки
models = []
for i in tqdm(params_cat):
    catboost_model = CatBoostClassifier(verbose=False, **i)
    models.append(catboost_model.fit(X,y))

for i in tqdm(params_xgb):
    model_xgb = XGBClassifier(**i)
    models.append(model_xgb.fit(X.drop(cat_col, axis=1),y))
    # models.append(stratified(X, y, i, n_splits=20, test_size=0.2, random_state=142)[1])
    # print('----------------------------------------------')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
t_d = df_transactions.groupby(['user_id','day'])['day'].count() 
t1 = t_d[t_d>20].unstack()
t2 = df_train[['user_id']].merge(t1, on='user_id')
#Объедененные фичи
t = pd.read_csv('features_X_train__v3.csv')
t = t[t['user_id'].isin(t2['user_id'])]
X = t.drop('target', axis=1)
y = t['target']

X_sub = pd.read_csv('features_X_test__v3.csv')
#Определение категориальных
cat_col = X.select_dtypes(include=['object']).columns.tolist()
y.shape, X.shape
# Out:
# ((296,), (296, 1154))

# %%
y.value_counts()
# Out:
# target
# 0    231
# 1     65
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,\
                        test_size = 0.20, random_state = 142, stratify=y)

# %%
y_train.value_counts()
# Out:
# target
# 0    184
# 1     52
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# target
# 0    47
# 1    13
# Name: count, dtype: int64

# %%
xgb = XGBClassifier(**best_xgb_params_2)
xgb.fit(x_train.drop(cat_col, axis=1),y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.11467178668260138, device='cuda',
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.31412508230969277,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints=None, learning_rate=0.011748077668768182,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=12, max_leaves=None,
#               min_child_weight=41, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=628, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(classification_report(y_test, xgb.predict(x_test.drop(cat_col, axis=1))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        47
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.78        60
#    macro avg       0.39      0.50      0.44        60
# weighted avg       0.61      0.78      0.69        60

# %%
print(f'Concordance Index: {concordance_index(y_test, xgb.predict_proba(x_test.drop(cat_col, axis=1))[:,1])}')
# Out:
# Concordance Index: 0.5

# %%
xgb.fit(X.drop(cat_col, axis=1),y)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.11467178668260138, device='cuda',
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.31412508230969277,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints=None, learning_rate=0.011748077668768182,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=12, max_leaves=None,
#               min_child_weight=41, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=628, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(f'Concordance Index: {concordance_index(y_test, xgb.predict_proba(x_test.drop(cat_col, axis=1))[:,1])}')
# Out:
# Concordance Index: 0.5

# %% [markdown]
# # SUBMISSION

# %%
df_sub = pd.read_csv('sample_submit_naive.csv')
X_sub = pd.read_csv('features_X_test__v3.csv')
df_sub_2 = df_sub.copy()

t2 = df_sub[['user_id']].merge(t1, on='user_id')
df_sub_1 = df_sub[~df_sub['user_id'].isin(t2['user_id'])]
df_sub_2 = df_sub_2[df_sub['user_id'].isin(t2['user_id'])]
df_sub_1.shape, df_sub_2.shape, df_sub.shape
# Out:
# ((31842, 2), (158, 2), (32000, 2))

# %%
X_sub_1 = df_sub_1[['user_id']].merge(X_sub, on='user_id')
X_sub_1 = X_sub_1[X.columns]

# %%
predictions = []
n = 0
for i in models:
    n +=1
    if n <= len(params_cat):
        predictions.append(i.predict_proba(X_sub_1)[:,1])
    else:
        predictions.append(i.predict_proba(X_sub_1.drop(cat_col, axis=1))[:,1])

# X_padded_test = torch.tensor(MinMaxScaler(feature_range=(0, 15)).fit_transform(X_sub_1.drop(cat_col, axis=1)))
# model.eval().to('cpu')  # переводим модель в режим оценки
# with torch.no_grad():  # отключаем вычисление градиентов
#             outputs = model(X_padded_test)
#             predictions.append(outputs.view(-1).to('cpu').numpy())

# %%
weights = list(best_weights.values())
weights
# Out:
# [0.05691356649453222,
#  0.01869011710038887,
#  0.05760203363004765,
#  0.4059237663923347,
#  0.03555506070606728,
#  0.22473946451953958,
#  0.0008350492754695127,
#  0.982611784076993,
#  0.35421913240010755]

# %%
X_sub_2 = df_sub_2[['user_id']].merge(X_sub, on='user_id')
X_sub_2 = X_sub_2[X.columns]

# %%
predictions_sub = []
n = 0
for i in models:
    n +=1
    if n <= len(params_cat):
        predictions_sub.append(i.predict_proba(X_sub_2)[:,1])
    else:
        predictions_sub.append(i.predict_proba(X_sub_2.drop(cat_col, axis=1))[:,1])

# X_padded_test = torch.tensor(MinMaxScaler(feature_range=(0, 15)).fit_transform(X_sub_2.drop(cat_col, axis=1)))
# model.eval().to('cpu')  # переводим модель в режим оценки
# with torch.no_grad():  # отключаем вычисление градиентов
#             outputs = model(X_padded_test)
#             predictions_sub.append(outputs.view(-1).to('cpu').numpy())

# %%
df_sub_1['predict'] = np.average(predictions, axis=0, weights=weights)
# для непонятной выборки предсказание
df_sub_2['predict'] = np.average(predictions_sub, axis=0, weights=weights) #best_fpr,  best_tpr, np.average(predictions_sub, axis=0, weights=weights)

# %%
df_sub  = pd.concat([df_sub_1, df_sub_2])
df_sub
# Out:
#        user_id  predict
# 0            9     0.01
# 1           61     0.02
# 2           62     0.03
# 3           80     0.01
# 4           88     0.14
# ...        ...      ...
# 30484   525643     0.50
# 31332   539688     0.27
# 31691   547912     0.46
# 31897   554211     0.49
# 31978   558238     0.53
#
# [32000 rows x 2 columns]

# %%
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")
df_sub.to_csv(f'sub_{current_time}.csv', index=False)
